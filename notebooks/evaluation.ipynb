# %%
import os, sys, json
import numpy as np
import torch
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader

PROJECT_PATH = "/Users/manish/Documents/GitHub/Crop-disease-detection"
SRC_PATH  = os.path.join(PROJECT_PATH, "src")

for p in [PROJECT_PATH, SRC_PATH]:
    if p not in sys.path:
        sys.path.insert(0, p)

from config import CFG
from data_loader import prepare_data, LeafDataset, get_transforms
from evaluator import (load_model, predict, show_accuracy, show_metrics, show_confusion, plot_history)
print("Setup complete")
# Out:
# Setup complete

# %% [markdown]
# ---
# ## Step 1 — Learning Curves
#
# Shows how accuracy and loss changed during training for each setting.

# %%
for setting in ["baseline", "distorted", "distorted1", "augmented"]:
    hist_path = os.path.join(CFG["RESULTS_DIR"], f"MobileNetV2_{setting}_history.json")
    if os.path.exists(hist_path):
        print(f"\nMobileNetV2  |  {setting}")
        plot_history("MobileNetV2", setting, CFG)
    else:
        print(f"  Skipping {setting} — not trained yet")
# Out:
# MobileNetV2  |  baseline
# MobileNetV2  |  distorted
# MobileNetV2  |  distorted1
#   Skipping augmented — not trained yet

# %% [markdown]
# ---
# ## Step 3 — Load Test Datasets

# %%
def load_test_only(images_path, labels_path, cfg):
    images = np.load(images_path)
    labels = np.load(labels_path, allow_pickle=True)
    enc = LabelEncoder()
    labels_int = enc.fit_transform(labels)
    class_names = list(enc.classes_)
    _, X_test, _, y_test = train_test_split(
        images, labels_int,
        test_size=cfg["TEST_SIZE"], random_state=cfg["SEED"], stratify=labels_int,
    )
    _, val_tf = get_transforms(cfg)
    loader = DataLoader(
        LeafDataset(X_test, y_test, val_tf),
        batch_size=cfg["BATCH_SIZE"], shuffle=False, num_workers=cfg["NUM_WORKERS"],
    )
    print(f"Test images: {len(y_test)}")
    return loader, y_test, class_names

print("Loading clean test set")
loader_clean, y_test_clean, class_names = load_test_only(CFG["CLEAN_IMAGES"], CFG["CLEAN_LABELS"], CFG)

print("Loading droplet test set 1")
loader_drop, y_test_drop, _ = load_test_only(CFG["DROP_IMAGES"], CFG["DROP_LABELS"], CFG)

print("Loading droplet test set 2")
loader_drop2, y_test_drop2, _ = load_test_only(CFG["DROP_IMAGES_1"], CFG["DROP_LABELS_1"], CFG)
# Out:
# Loading clean test set
# Test images: 10861
# Loading droplet test set 1
# Test images: 10861
# Loading droplet test set 2
# Test images: 10861

# %% [markdown]
# ---
# ## Baseline — Clean Images
#
# Run predictions once, then use in the 3 cells below.

# %%
print("Loading saved models")

model_baseline   = load_model("MobileNetV2", "baseline",   CFG)
model_distorted  = load_model("MobileNetV2", "distorted",  CFG)
model_distorted1 = load_model("MobileNetV2", "distorted1", CFG)
# Out:
# Loading saved models
#   Total parameters    : 2,272,550
#  Loaded: MobileNetV2_baseline_best.pth
#   Total parameters    : 2,272,550
#  Loaded: MobileNetV2_distorted_best.pth
#   Total parameters    : 2,272,550
#  Loaded: MobileNetV2_distorted1_best.pth

# %%
# Run predictions — call this once before the 3 cells below
y_pred_baseline, y_true_baseline = predict(model_baseline, loader_clean, CFG)
# Out:
#   Predictions ready — 10,861 test images

# %% [markdown]
# ### Baseline — Cell 1: Test Accuracy

# %%
show_accuracy(y_pred_baseline, y_true_baseline, "MobileNetV2", "baseline")
# Out:
# ==================================================
#   MobileNetV2  |  BASELINE
# ==================================================
#
#   Test Accuracy : 99.79%

# %% [markdown]
# ### Baseline — Cell 2: Precision / Recall / F1

# %%
show_metrics(y_pred_baseline, y_true_baseline, class_names, "MobileNetV2", "baseline", CFG)
# Out:
#  Overall Metrics
#   ──────────────────────────────────────────────────
#   Metric                 Macro Avg   Weighted Avg
#   ──────────────────────────────────────────────────
#   Precision                 99.59%         99.79%
#   Recall                    99.74%         99.79%
#   F1-Score                  99.66%         99.79%
#
#  Per Class Metrics
#   ──────────────────────────────────────────────────
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab     1.0000    0.9921    0.9960       126
#                                  Apple___Black_rot     0.9920    1.0000    0.9960       124
#                           Apple___Cedar_apple_rust     1.0000    1.0000    1.0000        55
#                                    Apple___healthy     1.0000    1.0000    1.0000       329
#                                Blueberry___healthy     1.0000    1.0000    1.0000       300
#           Cherry_(including_sour)___Powdery_mildew     1.0000    1.0000    1.0000       210
#                  Cherry_(including_sour)___healthy     1.0000    1.0000    1.0000       171
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot     0.9439    0.9806    0.9619       103
#                        Corn_(maize)___Common_rust_     1.0000    1.0000    1.0000       239
#                Corn_(maize)___Northern_Leaf_Blight     0.9897    0.9746    0.9821       197
#                             Corn_(maize)___healthy     1.0000    1.0000    1.0000       232
#                                  Grape___Black_rot     1.0000    1.0000    1.0000       236
#                       Grape___Esca_(Black_Measles)     1.0000    1.0000    1.0000       277
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)     1.0000    1.0000    1.0000       215
#                                    Grape___healthy     1.0000    1.0000    1.0000        85
#           Orange___Haunglongbing_(Citrus_greening)     1.0000    1.0000    1.0000      1102
#                             Peach___Bacterial_spot     1.0000    1.0000    1.0000       460
#                                    Peach___healthy     1.0000    1.0000    1.0000        72
#                      Pepper,_bell___Bacterial_spot     1.0000    1.0000    1.0000       199
#                             Pepper,_bell___healthy     1.0000    0.9932    0.9966       296
#                              Potato___Early_blight     1.0000    1.0000    1.0000       200
#                               Potato___Late_blight     1.0000    1.0000    1.0000       200
#                                   Potato___healthy     0.9677    1.0000    0.9836        30
#                                Raspberry___healthy     1.0000    1.0000    1.0000        74
#                                  Soybean___healthy     1.0000    1.0000    1.0000      1018
#                            Squash___Powdery_mildew     1.0000    1.0000    1.0000       367
#                           Strawberry___Leaf_scorch     1.0000    0.9955    0.9977       222
#                               Strawberry___healthy     1.0000    1.0000    1.0000        91
#                            Tomato___Bacterial_spot     1.0000    0.9953    0.9976       425
#                              Tomato___Early_blight     0.9900    0.9900    0.9900       200
#                               Tomato___Late_blight     0.9922    1.0000    0.9961       382
#                                 Tomato___Leaf_Mold     1.0000    1.0000    1.0000       190
#                        Tomato___Septoria_leaf_spot     1.0000    1.0000    1.0000       354
#      Tomato___Spider_mites Two-spotted_spider_mite     0.9882    0.9970    0.9926       335
#                               Tomato___Target_Spot     0.9928    0.9858    0.9893       281
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus     0.9991    0.9972    0.9981      1071
#                       Tomato___Tomato_mosaic_virus     0.9868    1.0000    0.9934        75
#                                   Tomato___healthy     1.0000    1.0000    1.0000       318
#
#                                           accuracy                         0.9979     10861
#                                          macro avg     0.9959    0.9974    0.9966     10861
#                                       weighted avg     0.9979    0.9979    0.9979     10861

# %% [markdown]
# ### Baseline — Cell 3: Confusion Matrix + TP/FP/FN/TN

# %%
show_confusion(y_pred_baseline, y_true_baseline, class_names)

# %% [markdown]
# ---
# ## Distorted — Droplet Dataset 1

# %%
y_pred_distorted, y_true_distorted = predict(model_distorted, loader_drop, CFG)
# Out:
#   Predictions ready — 10,861 test images

# %% [markdown]
# ### Distorted — Cell 1: Test Accuracy

# %%
show_accuracy(y_pred_distorted, y_true_distorted, "MobileNetV2", "distorted")
# Out:
# ==================================================
#   MobileNetV2  |  DISTORTED
# ==================================================
#
#   Test Accuracy : 99.67%

# %% [markdown]
# ### Distorted — Cell 2: Precision / Recall / F1

# %%
show_metrics(y_pred_distorted, y_true_distorted, class_names, "MobileNetV2", "distorted", CFG)
# Out:
#  Overall Metrics
#   ──────────────────────────────────────────────────
#   Metric                 Macro Avg   Weighted Avg
#   ──────────────────────────────────────────────────
#   Precision                 99.57%         99.67%
#   Recall                    99.57%         99.67%
#   F1-Score                  99.57%         99.67%
#
#  Per Class Metrics
#   ──────────────────────────────────────────────────
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab     1.0000    1.0000    1.0000       126
#                                  Apple___Black_rot     1.0000    1.0000    1.0000       124
#                           Apple___Cedar_apple_rust     1.0000    1.0000    1.0000        55
#                                    Apple___healthy     1.0000    0.9939    0.9970       329
#                                Blueberry___healthy     0.9967    1.0000    0.9983       300
#           Cherry_(including_sour)___Powdery_mildew     1.0000    1.0000    1.0000       210
#                  Cherry_(including_sour)___healthy     1.0000    1.0000    1.0000       171
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot     0.9434    0.9709    0.9569       103
#                        Corn_(maize)___Common_rust_     1.0000    0.9958    0.9979       239
#                Corn_(maize)___Northern_Leaf_Blight     0.9797    0.9797    0.9797       197
#                             Corn_(maize)___healthy     1.0000    0.9957    0.9978       232
#                                  Grape___Black_rot     0.9958    1.0000    0.9979       236
#                       Grape___Esca_(Black_Measles)     1.0000    0.9964    0.9982       277
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)     1.0000    1.0000    1.0000       215
#                                    Grape___healthy     1.0000    1.0000    1.0000        85
#           Orange___Haunglongbing_(Citrus_greening)     1.0000    1.0000    1.0000      1102
#                             Peach___Bacterial_spot     0.9978    1.0000    0.9989       460
#                                    Peach___healthy     1.0000    0.9861    0.9930        72
#                      Pepper,_bell___Bacterial_spot     1.0000    1.0000    1.0000       199
#                             Pepper,_bell___healthy     1.0000    0.9966    0.9983       296
#                              Potato___Early_blight     0.9950    1.0000    0.9975       200
#                               Potato___Late_blight     0.9950    1.0000    0.9975       200
#                                   Potato___healthy     1.0000    1.0000    1.0000        30
#                                Raspberry___healthy     1.0000    1.0000    1.0000        74
#                                  Soybean___healthy     0.9990    1.0000    0.9995      1018
#                            Squash___Powdery_mildew     1.0000    1.0000    1.0000       367
#                           Strawberry___Leaf_scorch     0.9955    0.9955    0.9955       222
#                               Strawberry___healthy     1.0000    1.0000    1.0000        91
#                            Tomato___Bacterial_spot     1.0000    0.9953    0.9976       425
#                              Tomato___Early_blight     0.9848    0.9700    0.9773       200
#                               Tomato___Late_blight     0.9921    0.9869    0.9895       382
#                                 Tomato___Leaf_Mold     1.0000    1.0000    1.0000       190
#                        Tomato___Septoria_leaf_spot     0.9916    1.0000    0.9958       354
#      Tomato___Spider_mites Two-spotted_spider_mite     1.0000    0.9791    0.9894       335
#                               Tomato___Target_Spot     0.9722    0.9964    0.9842       281
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus     0.9981    1.0000    0.9991      1071
#                       Tomato___Tomato_mosaic_virus     1.0000    1.0000    1.0000        75
#                                   Tomato___healthy     1.0000    1.0000    1.0000       318
#
#                                           accuracy                         0.9967     10861
#                                          macro avg     0.9957    0.9957    0.9957     10861
#                                       weighted avg     0.9967    0.9967    0.9967     10861

# %% [markdown]
# ### Distorted — Cell 3: Confusion Matrix + TP/FP/FN/TN

# %%
show_confusion(y_pred_distorted, y_true_distorted, class_names)

# %% [markdown]
# ---
# ## Distorted 2 — Droplet Dataset 2

# %%
y_pred_distorted2, y_true_distorted2 = predict(model_distorted1, loader_drop2, CFG)
# Out:
#   Predictions ready — 10,861 test images

# %% [markdown]
# ### Distorted 2 — Cell 1: Test Accuracy

# %%
show_accuracy(y_pred_distorted2, y_true_distorted2, "MobileNetV2", "distorted1")
# Out:
# ==================================================
#   MobileNetV2  |  DISTORTED1
# ==================================================
#
#   Test Accuracy : 99.59%

# %% [markdown]
# ### Distorted 2 — Cell 2: Precision / Recall / F1

# %%
show_metrics(y_pred_distorted2, y_true_distorted2, class_names, "MobileNetV2", "distorted2", CFG)
# Out:
#  Overall Metrics
#   ──────────────────────────────────────────────────
#   Metric                 Macro Avg   Weighted Avg
#   ──────────────────────────────────────────────────
#   Precision                 99.36%         99.59%
#   Recall                    99.46%         99.59%
#   F1-Score                  99.41%         99.59%
#
#  Per Class Metrics
#   ──────────────────────────────────────────────────
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab     1.0000    1.0000    1.0000       126
#                                  Apple___Black_rot     1.0000    1.0000    1.0000       124
#                           Apple___Cedar_apple_rust     1.0000    1.0000    1.0000        55
#                                    Apple___healthy     1.0000    0.9939    0.9970       329
#                                Blueberry___healthy     1.0000    0.9967    0.9983       300
#           Cherry_(including_sour)___Powdery_mildew     1.0000    1.0000    1.0000       210
#                  Cherry_(including_sour)___healthy     1.0000    1.0000    1.0000       171
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot     0.9159    0.9515    0.9333       103
#                        Corn_(maize)___Common_rust_     1.0000    0.9958    0.9979       239
#                Corn_(maize)___Northern_Leaf_Blight     0.9744    0.9645    0.9694       197
#                             Corn_(maize)___healthy     1.0000    1.0000    1.0000       232
#                                  Grape___Black_rot     1.0000    1.0000    1.0000       236
#                       Grape___Esca_(Black_Measles)     1.0000    1.0000    1.0000       277
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)     1.0000    1.0000    1.0000       215
#                                    Grape___healthy     1.0000    1.0000    1.0000        85
#           Orange___Haunglongbing_(Citrus_greening)     1.0000    1.0000    1.0000      1102
#                             Peach___Bacterial_spot     0.9978    1.0000    0.9989       460
#                                    Peach___healthy     0.9730    1.0000    0.9863        72
#                      Pepper,_bell___Bacterial_spot     1.0000    1.0000    1.0000       199
#                             Pepper,_bell___healthy     1.0000    0.9966    0.9983       296
#                              Potato___Early_blight     1.0000    0.9950    0.9975       200
#                               Potato___Late_blight     1.0000    0.9850    0.9924       200
#                                   Potato___healthy     1.0000    1.0000    1.0000        30
#                                Raspberry___healthy     1.0000    1.0000    1.0000        74
#                                  Soybean___healthy     1.0000    1.0000    1.0000      1018
#                            Squash___Powdery_mildew     1.0000    1.0000    1.0000       367
#                           Strawberry___Leaf_scorch     0.9955    0.9955    0.9955       222
#                               Strawberry___healthy     1.0000    1.0000    1.0000        91
#                            Tomato___Bacterial_spot     0.9976    0.9929    0.9953       425
#                              Tomato___Early_blight     0.9515    0.9800    0.9655       200
#                               Tomato___Late_blight     0.9793    0.9921    0.9857       382
#                                 Tomato___Leaf_Mold     0.9896    1.0000    0.9948       190
#                        Tomato___Septoria_leaf_spot     0.9972    0.9887    0.9929       354
#      Tomato___Spider_mites Two-spotted_spider_mite     0.9940    0.9970    0.9955       335
#                               Tomato___Target_Spot     0.9929    0.9893    0.9911       281
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus     0.9991    0.9972    0.9981      1071
#                       Tomato___Tomato_mosaic_virus     1.0000    0.9867    0.9933        75
#                                   Tomato___healthy     1.0000    0.9969    0.9984       318
#
#                                           accuracy                         0.9959     10861
#                                          macro avg     0.9936    0.9946    0.9941     10861
#                                       weighted avg     0.9959    0.9959    0.9959     10861

# %% [markdown]
# ### Distorted 2 — Cell 3: Confusion Matrix + TP/FP/FN/TN

# %%
show_confusion(y_pred_distorted2, y_true_distorted2, class_names)
